# %%
import pandas as pd
import musicbrainzngs as music
import time

rock_bands = [
    "AC/DC", "Aerosmith", "Alice Cooper", "Allman Brothers Band", "Bad Company", "Black Sabbath", 
    "Blue Öyster Cult", "Boston", "Cheap Trick", "Creedence Clearwater Revival", "Deep Purple", 
    "Def Leppard", "Derek and the Dominos", "Eagles", "Fleetwood Mac", "Foreigner", "Genesis", 
    "Grateful Dead", "Heart", "Iron Maiden", "Jethro Tull", "Judas Priest", "Kansas", "KISS", 
    "Led Zeppelin", "Lynyrd Skynyrd", "Motörhead", "Nazareth", "Pink Floyd", "Queen", "Rainbow", 
    "REO Speedwagon", "Rush", "Santana", "Scorpions", "Steely Dan", "Styx", "Ted Nugent", "The Band", 
    "The Doors", "The Police", "The Rolling Stones", "The Who", "Thin Lizzy", "Tom Petty and the Heartbreakers", 
    "Triumph", "UFO", "Uriah Heep", "Van Halen", "Yes", "ZZ Top", "Bon Jovi", "Bruce Springsteen", 
    "Dire Straits", "Guns N' Roses", "INXS", "Journey", "Metallica", "Nirvana", "Pearl Jam", 
    "Poison", "R.E.M.", "Red Hot Chili Peppers", "Roxy Music", "Soundgarden", "The Cure", "The Smiths", 
    "U2", "Whitesnake", "Winger", "Warrant", "10cc", "Argent", "Asia", "Bachman-Turner Overdrive", 
    "Badfinger", "Big Star", "Blind Faith", "The Byrds", "Camel", "Can", "Caravan", "Cheap Trick", 
    "Chicago", "Colosseum", "Cream", "Crosby, Stills, Nash & Young", "David Bowie", "Devo", "Doobie Brothers", 
    "Electric Light Orchestra", "Emerson, Lake & Palmer", "Fairport Convention", "Focus", "Free", 
    "Gentle Giant", "Hawkwind", "Humble Pie", "King Crimson", "Little Feat", "Love", "Manfred Mann's Earth Band", 
    "MC5", "Mountain", "Mott the Hoople", "New York Dolls", "Nick Cave and the Bad Seeds", "Pavement", 
    "Pixies", "Procol Harum", "Public Image Ltd.", "Renaissance", "Roxy Music", "Slade", "Small Faces", 
    "Spinal Tap", "Steppenwolf", "The Animals", "The Beach Boys", "The Clash", "The Kinks", "The Monkees", 
    "The Move", "The Troggs", "Traffic", "Velvet Underground", "Wings", "XTC", "Yes", "Zombies", "ZZ Top", 
    "Anthrax", "Black Crowes", "Blondie", "Bush", "Counting Crows", "Dinosaur Jr.", "Faith No More", 
    "Fugazi", "Green Day", "Hole", "Jane's Addiction", "Live", "Meat Puppets", "Nine Inch Nails", "Oasis", 
    "Offspring", "Pixies", "Pulp", "Radiohead", "Rage Against the Machine", "Screaming Trees", 
    "Sex Pistols", "Smashing Pumpkins", "Stone Temple Pilots", "Suicidal Tendencies", "T. Rex", 
    "Talking Heads", "The B-52's", "The Breeders", "The Jam", "The Pretenders", "The Replacements", 
    "The Stranglers", "The Verve", "They Might Be Giants", "Tool", "Violent Femmes", "Weezer", "Wilco", 
    "Big Country", "Blue Cheer", "The Cars", "Clash", "Damn Yankees", "Dream Theater", "Extreme", 
    "Fastway", "Goo Goo Dolls", "Hanoi Rocks", "Helmet", "Hootie & the Blowfish", "Hüsker Dü", 
    "Iron Butterfly", "L.A. Guns", "Living Colour", "Love and Rockets", "Marillion", "Meat Loaf", 
    "Midnight Oil", "Ministry", "Mr. Big", "Night Ranger", "The Outlaws", "Pat Benatar", "Peter Frampton", 
    "Primus", "Queensrÿche", "Saga", "Savatage", "Sepultura", "Silverchair", "Skid Row", "Slayer", 
    "Sonic Youth", "Spandau Ballet", "Status Quo", "Stryper", "Sugar", "Tesla", "The Cult", 
    "The Fabulous Thunderbirds", "The Guess Who", "The Lemonheads", "The Meat Puppets", "The Moody Blues", 
    "The Outfield", "The Pogues", "The Scorpions", "The Stone Roses", "The Traveling Wilburys", 
    "The Tubes", "The Zombies", "Third Eye Blind", "Toto", "Tygers of Pan Tang", "Ugly Kid Joe", 
    "Van Der Graaf Generator", "W.A.S.P.", "War", "Ween", "White Lion", "Widespread Panic", "X", 
    "Yardbirds", "Yngwie Malmsteen", "Zebra", "Ziggy Marley and the Melody Makers"
]

# %%
for band in rock_bands:
    print(band)
    music.search_artists(artist=band)
# Out:
# AC/DC
# Aerosmith
# Alice Cooper
# Allman Brothers Band
# Bad Company
# Black Sabbath
# Blue Öyster Cult
# Boston
# Cheap Trick
# Creedence Clearwater Revival
# Deep Purple
# Def Leppard
# Derek and the Dominos
# Eagles
# Fleetwood Mac
# Foreigner
# Genesis
# Grateful Dead
# Heart
# Iron Maiden
# Jethro Tull
# Judas Priest
# Kansas
# KISS
# Led Zeppelin
# Lynyrd Skynyrd
# Motörhead
# Nazareth
# Pink Floyd
# Queen
# Rainbow
# REO Speedwagon
# Rush
# Santana
# Scorpions
# Steely Dan
# Styx
# Ted Nugent
# The Band
# The Doors
# The Police
# The Rolling Stones
# The Who
# Thin Lizzy
# Tom Petty and the Heartbreakers
# Triumph
# UFO
# Uriah Heep
# Van Halen
# Yes
# ZZ Top
# Bon Jovi
# Bruce Springsteen
# Dire Straits
# Guns N' Roses
# INXS
# Journey
# Metallica
# Nirvana
# Pearl Jam
# Poison
# R.E.M.
# Red Hot Chili Peppers
# Roxy Music
# Soundgarden
# The Cure
# The Smiths
# U2
# Whitesnake
# Winger
# Warrant
# 10cc
# Argent
# Asia
# Bachman-Turner Overdrive
# Badfinger
# Big Star
# Blind Faith
# The Byrds
# Camel
# Can
# Caravan
# Cheap Trick
# Chicago
# Colosseum
# Cream
# Crosby, Stills, Nash & Young
# David Bowie
# Devo
# Doobie Brothers
# Electric Light Orchestra
# Emerson, Lake & Palmer
# Fairport Convention
# Focus
# Free
# Gentle Giant
# Hawkwind
# Humble Pie
# King Crimson
# Little Feat
# Love
# Manfred Mann's Earth Band
# MC5
# Mountain
# Mott the Hoople
# New York Dolls
# Nick Cave and the Bad Seeds
# Pavement
# Pixies
# Procol Harum
# Public Image Ltd.
# Renaissance
# Roxy Music
# Slade
# Small Faces
# Spinal Tap
# Steppenwolf
# The Animals
# The Beach Boys
# The Clash
# The Kinks
# The Monkees
# The Move
# The Troggs
# Traffic
# Velvet Underground
# Wings
# XTC
# Yes
# Zombies
# ZZ Top
# Anthrax
# Black Crowes
# Blondie
# Bush
# Counting Crows
# Dinosaur Jr.
# Faith No More
# Fugazi
# Green Day
# Hole
# Jane's Addiction
# Live
# Meat Puppets
# Nine Inch Nails
# Oasis
# Offspring
# Pixies
# Pulp
# Radiohead
# Rage Against the Machine
# Screaming Trees
# Sex Pistols
# Smashing Pumpkins
# Stone Temple Pilots
# Suicidal Tendencies
# T. Rex
# Talking Heads
# The B-52's
# The Breeders
# The Jam
# The Pretenders
# The Replacements
# The Stranglers
# The Verve
# They Might Be Giants
# Tool
# Violent Femmes
# Weezer
# Wilco
# Big Country
# Blue Cheer
# The Cars
# Clash
# Damn Yankees
# Dream Theater
# Extreme
# Fastway
# Goo Goo Dolls
# Hanoi Rocks
# Helmet
# Hootie & the Blowfish
# Hüsker Dü
# Iron Butterfly
# L.A. Guns
# Living Colour
# Love and Rockets
# Marillion
# Meat Loaf
# Midnight Oil
# Ministry
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 for band in rock_bands:
#       2     print(band)
# ----> 3     music.search_artists(artist=band)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:935, in search_artists(query, limit, offset, strict, **fields)
#     930 @_docstring_search("artist")
#     931 def search_artists(query='', limit=None, offset=None, strict=False, **fields):
#     932     """Search for artists and return a dict with an 'artist-list' key.
#     933
#     934     *Available search fields*: {fields}"""
# --> 935     return _do_mb_search('artist', query, fields, limit, offset, strict)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:782, in _do_mb_search(entity, query, fields, limit, offset, strict)
#     779 if offset:
#     780 	params['offset'] = str(offset)
# --> 782 return _do_mb_query(entity, '', [], params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:728, in _do_mb_query(entity, id, includes, params)
#     726 # Build the endpoint components.
#     727 path = '%s/%s' % (entity, id)
# --> 728 return _mb_request(path, 'GET', auth_required, args=args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:411, in _rate_limit.__call__(self, *args, **kwargs)
#     409 # Delay if necessary.
#     410 while self.remaining_requests < 0.999:
# --> 411     time.sleep((1.0 - self.remaining_requests) *
#     412                (limit_requests / limit_interval))
#     413     self._update_remaining()
#     415 # Call the original function, "paying" for this call.
#
# KeyboardInterrupt:

# %%
test_case = music.search_artists('Jethro Tull')

# %%
test_case['artist-list'][0]
# Out:
# [{'id': 'ece57992-dc2e-4f67-a269-fa43626c1a3d',
#   'type': 'Group',
#   'ext:score': '100',
#   'name': 'Jethro Tull',
#   'sort-name': 'Jethro Tull',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': 'fce4afff-8d49-4f1f-977a-10edbe839331',
#    'type': 'Subdivision',
#    'name': 'Luton',
#    'sort-name': 'Luton',
#    'life-span': {'ended': 'false'}},
#   'isni-list': ['0000000123374070'],
#   'life-span': {'begin': '1967-12', 'ended': 'false'},
#   'alias-list': [{'locale': 'ja',
#     'sort-name': 'ジェ入ロ',
#     'type': 'Artist name',
#     'primary': 'primary',
#     'alias': 'ジェ入ロ'},
#    {'sort-name': 'Jetro Tull', 'alias': 'Jetro Tull'},
#    {'sort-name': 'Tull', 'alias': 'Tull'},
#    {'sort-name': 'Jethrp Tull', 'alias': 'Jethrp Tull'}],
#   'tag-list': [{'count': '4', 'name': 'rock'},
#    {'count': '12', 'name': 'progressive rock'},
#    {'count': '0', 'name': 'folk'},
#    {'count': '1', 'name': 'british'},
#    {'count': '0', 'name': 'uk'},
#    {'count': '4', 'name': 'hard rock'},
#    {'count': '10', 'name': 'folk rock'},
#    {'count': '5', 'name': 'blues rock'},
#    {'count': '1', 'name': 'art rock'},
#    {'count': '2', 'name': 'classic rock'},
#    {'count': '2', 'name': 'progressive folk'},
#    {'count': '0', 'name': 'english'},
#    {'count': '0', 'name': 'classic pop and rock'},
#    {'count': '1', 'name': 'christmas music'},
#    {'count': '0', 'name': 'prog folk'}]},
#  {'id': '12fffb1f-39af-4efe-9426-92e05bb651d1',
#   'type': 'Person',
#   'ext:score': '61',
#   'name': 'Ian Anderson',
#   'sort-name': 'Anderson, Ian',
#   'gender': 'male',
#   'area': {'id': 'a484c622-84a2-4862-a436-e9055991b542',
#    'type': 'City',
#    'name': 'Minety',
#    'sort-name': 'Minety',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': '8802de90-150b-48f6-8f83-64a9601ad014',
#    'type': 'City',
#    'name': 'Dunfermline',
#    'sort-name': 'Dunfermline',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'of Jethro Tull',
#   'ipi-list': ['00086990813'],
#   'isni-list': ['0000000117553806'],
#   'life-span': {'begin': '1947-08-10', 'ended': 'false'},
#   'alias-list': [{'sort-name': 'Anderson, Ian Scott',
#     'type': 'Legal name',
#     'alias': 'Ian Scott Anderson'},
#    {'sort-name': "Jethro Tull's Ian Anderson",
#     'alias': "Jethro Tull's Ian Anderson"}],
#   'tag-list': [{'count': '1', 'name': 'rock'},
#    {'count': '1', 'name': 'progressive rock'},
#    {'count': '3', 'name': 'folk'},
#    {'count': '1', 'name': 'singer-songwriter'},
#    {'count': '3', 'name': 'folk rock'},
#    {'count': '2', 'name': 'acoustic rock'},
#    {'count': '2', 'name': 'pop rock'},
#    {'count': '1', 'name': 'progressive folk'},
#    {'count': '0', 'name': 'classical crossover'},
#    {'count': '2', 'name': 'progressive/folk-rock'}]},
#  {'id': '284047a4-34dc-42d2-9dcf-2dbe682b31c9',
#   'type': 'Group',
#   'ext:score': '58',
#   'name': 'The John Evan Band',
#   'sort-name': 'Evan, John, Band, The',
#   'life-span': {'begin': '1965', 'end': '1967', 'ended': 'true'},
#   'alias-list': [{'locale': 'en_GB',
#     'sort-name': 'Jethro Tull',
#     'begin-date': '1967-12',
#     'alias': 'Jethro Tull'},
#    {'locale': 'en_GB',
#     'sort-name': 'John Evan Smash, The',
#     'begin-date': '1965',
#     'end-date': '1967',
#     'alias': 'The John Evan Smash'}]},
#  {'id': 'da425855-131b-4034-9bbc-99c92bbd8331',
#   'type': 'Person',
#   'ext:score': '47',
#   'name': 'David Goodier',
#   'sort-name': 'Goodier, David',
#   'gender': 'male',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Jethro Tull bassist',
#   'isni-list': ['0000000053527675'],
#   'life-span': {'begin': '1954-09-13', 'ended': 'false'}},
#  {'id': '8e608ed8-5066-49a0-87b6-48cedd186d80',
#   'type': 'Group',
#   'ext:score': '41',
#   'name': 'GanzTull',
#   'sort-name': 'GanzTull',
#   'area': {'id': '2e725477-4471-4569-8e12-8d8ba5ba2d53',
#    'type': 'Subdivision',
#    'name': 'Central Denmark Region',
#    'sort-name': 'Central Denmark Region',
#    'life-span': {'begin': '2007-01-01', 'ended': 'false'}},
#   'disambiguation': 'Danish Jethro Tull tribute band',
#   'life-span': {'begin': '2020', 'ended': 'false'}},
#  {'id': 'e54203ac-f4ee-4970-a54f-78993f8b91a1',
#   'type': 'Person',
#   'ext:score': '39',
#   'name': 'Dee Palmer',
#   'sort-name': 'Palmer, Dee',
#   'gender': 'female',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': '0caff87a-4e9a-45a5-b35b-81d6e16c921d',
#    'type': 'City',
#    'name': 'Wolverhampton',
#    'sort-name': 'Wolverhampton',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'aka David Palmer, of Jethro Tull',
#   'ipi-list': ['00041123437', '00062233114'],
#   'isni-list': ['0000000114775104', '0000000115300311'],
#   'life-span': {'begin': '1937-07-02', 'ended': 'false'},
#   'alias-list': [{'sort-name': 'Dave Palmer',
#     'type': 'Search hint',
#     'alias': 'Dave Palmer'},
#    {'sort-name': 'Palmer, David',
#     'type': 'Legal name',
#     'begin-date': '1937',
#     'end-date': '1998',
#     'alias': 'David Palmer'}],
#   'tag-list': [{'count': '1', 'name': 'rock'}]},
#  {'id': 'a6158292-3a1a-45df-a28f-43d7836ea952',
#   'type': 'Group',
#   'ext:score': '38',
#   'name': 'Mother Goose',
#   'sort-name': 'Mother Goose',
#   'begin-area': {'id': '23d10872-f5ae-3f0c-bf55-332788a16ecb',
#    'type': 'Country',
#    'name': 'Sweden',
#    'sort-name': 'Sweden',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Jethro Tull Tribute Band from Sweden',
#   'life-span': {'ended': 'false'}},
#  {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#   'type': 'Person',
#   'ext:score': '36',
#   'name': 'Jethro Burns',
#   'sort-name': 'Burns, Jethro',
#   'gender': 'male',
#   'country': 'US',
#   'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#    'type': 'Country',
#    'name': 'United States',
#    'sort-name': 'United States',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': 'd10ba752-c9ce-4804-afc0-7ff94aa5d8d6',
#    'type': 'Subdivision',
#    'name': 'Georgia',
#    'sort-name': 'Georgia',
#    'life-span': {'ended': 'false'}},
#   'end-area': {'id': '860a21bd-92a4-462f-a000-3eefc57ed793',
#    'type': 'City',
#    'name': 'Evanston',
#    'sort-name': 'Evanston',
#    'life-span': {'ended': 'false'}},
#   'isni-list': ['0000000035669127'],
#   'life-span': {'begin': '1920-03-10', 'end': '1989-02-04', 'ended': 'true'},
#   'alias-list': [{'sort-name': 'Burns, Kenneth C.',
#     'alias': 'Kenneth C. Burns'},
#    {'sort-name': 'Kenneth C. "Jethro" Burns',
#     'alias': 'Kenneth C. "Jethro" Burns'},
#    {'sort-name': 'Burns, Kenneth Charles',
#     'type': 'Legal name',
#     'alias': 'Kenneth Charles Burns'}],
#   'tag-list': [{'count': '1', 'name': 'western swing'},
#    {'count': '1', 'name': 'bluegrass'}]},
#  {'id': '8f70025e-4a2a-4c42-b462-4b229e3d4737',
#   'type': 'Person',
#   'ext:score': '35',
#   'name': 'Jethro',
#   'sort-name': 'Jethro',
#   'gender': 'male',
#   'area': {'id': '7c71f821-98a0-4f1b-bf6b-87fe1d6c89f0',
#    'type': 'City',
#    'name': 'Tucson',
#    'sort-name': 'Tucson',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Rapper',
#   'life-span': {'begin': '1979', 'end': '2006', 'ended': 'true'}},
#  {'id': '94d2feed-b6b1-4058-b1f3-ceadb1fe9e1b',
#   'type': 'Person',
#   'ext:score': '35',
#   'name': 'Jethro',
#   'sort-name': 'Jethro',
#   'gender': 'male',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': '03d7eb23-c924-4e46-af72-a45f6ee04c8b',
#    'type': 'Subdivision',
#    'name': 'Cornwall',
#    'sort-name': 'Cornwall',
#    'life-span': {'ended': 'false'}},
#   'end-area': {'id': '27e496a5-2ad4-4d7e-a4ac-a3869b2bbad7',
#    'type': 'Subdivision',
#    'name': 'Plymouth',
#    'sort-name': 'Plymouth',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Cornish comedian',
#   'isni-list': ['000000049268703X'],
#   'life-span': {'begin': '1948-03-08', 'end': '2021-12-14', 'ended': 'true'},
#   'alias-list': [{'sort-name': 'Cornish Ambassador, The',
#     'type': 'Artist name',
#     'alias': 'The Cornish Ambassador'},
#    {'sort-name': 'Rowe, Geoffrey J.',
#     'type': 'Legal name',
#     'alias': 'Geoffrey J. Rowe'}],
#   'tag-list': [{'count': '1', 'name': 'comedy'},
#    {'count': '2', 'name': 'death by covid-19'}]},
#  {'id': 'f5a6bb71-f49d-4115-b285-fda004821497',
#   'type': 'Group',
#   'ext:score': '35',
#   'name': 'Homer & Jethro',
#   'sort-name': 'Homer & Jethro',
#   'country': 'US',
#   'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#    'type': 'Country',
#    'name': 'United States',
#    'sort-name': 'United States',
#    'life-span': {'ended': 'false'}},
#   'isni-list': ['0000000084163720'],
#   'life-span': {'begin': '1936', 'end': '1971', 'ended': 'true'},
#   'alias-list': [{'sort-name': 'Homer and Jethro',
#     'alias': 'Homer and Jethro'}],
#   'tag-list': [{'count': '1', 'name': 'country'},
#    {'count': '1', 'name': 'comedy'}]},
#  {'id': '1422e8f7-989b-41eb-aef9-246ac5544e82',
#   'type': 'Person',
#   'ext:score': '33',
#   'name': 'Giuliano Tull',
#   'sort-name': 'Tull, Giuliano',
#   'gender': 'male',
#   'country': 'IT',
#   'area': {'id': 'c6500277-9a3d-349b-bf30-41afdbf42add',
#    'type': 'Country',
#    'name': 'Italy',
#    'sort-name': 'Italy',
#    'life-span': {'ended': 'false'}},
#   'life-span': {'ended': 'false'}},
#  {'id': 'f695aad2-544b-4438-9677-34c9728f1aed',
#   'type': 'Person',
#   'ext:score': '33',
#   'name': 'Patrick Tull',
#   'sort-name': 'Tull, Patrick',
#   'gender': 'male',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': '9d5dd675-3cf4-4296-9e39-67865ebee758',
#    'type': 'Subdivision',
#    'name': 'England',
#    'sort-name': 'England',
#    'life-span': {'ended': 'false'}},
#   'end-area': {'id': '74e50e58-5deb-4b99-93a2-decbb365c07f',
#    'type': 'City',
#    'name': 'New York',
#    'sort-name': 'New York',
#    'life-span': {'ended': 'false'}},
#   'isni-list': ['0000000064032838'],
#   'life-span': {'begin': '1941-07-28', 'end': '2006-09-23', 'ended': 'true'}},
#  {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Fisher Tull',
#   'sort-name': 'Tull, Fisher',
#   'gender': 'male',
#   'country': 'US',
#   'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#    'type': 'Country',
#    'name': 'United States',
#    'sort-name': 'United States',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': 'a2e4f11b-99d1-4aa4-b184-4d6bc29d1365',
#    'type': 'City',
#    'name': 'Waco',
#    'sort-name': 'Waco',
#    'life-span': {'ended': 'false'}},
#   'end-area': {'id': '2e555843-28b6-471e-8791-9134f83cf3c4',
#    'type': 'City',
#    'name': 'Huntsville',
#    'sort-name': 'Huntsville',
#    'life-span': {'ended': 'false'}},
#   'isni-list': ['0000000112453400'],
#   'life-span': {'begin': '1934-09-23', 'end': '1994-08-23', 'ended': 'true'}},
#  {'id': 'b9369571-bb88-426a-af66-72d08c3d86bf',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Nadine Tull',
#   'sort-name': 'Tull, Nadine',
#   'gender': 'female',
#   'country': 'BB',
#   'area': {'id': 'e5d8d205-81d3-3cd3-8956-d5aaa0c0173f',
#    'type': 'Country',
#    'name': 'Barbados',
#    'sort-name': 'Barbados',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Caribbean-based Christian artist',
#   'life-span': {'ended': 'false'},
#   'tag-list': [{'count': '1', 'name': 'gospel'},
#    {'count': '1', 'name': 'contemporary christian'},
#    {'count': '1', 'name': 'inspirational'}]},
#  {'id': '376b3fda-8cb8-4a56-be04-a214e46ecec3',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Bob Tull',
#   'sort-name': 'Bob Tull',
#   'life-span': {'begin': '1981-02-22', 'ended': 'false'}},
#  {'id': '9ec2a013-4b79-4dfb-b15c-619290a018d4',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Tull Glazener',
#   'sort-name': 'Tull Glazener',
#   'gender': 'male',
#   'area': {'id': '3bb238a4-c2a4-44e5-9843-a63e71b17e83',
#    'type': 'City',
#    'name': 'Indianapolis',
#    'sort-name': 'Indianapolis',
#    'life-span': {'ended': 'false'}},
#   'life-span': {'ended': 'false'}},
#  {'id': '1062b9a7-fbc9-4f49-b372-24a3c9440194',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Dani Tull',
#   'sort-name': 'Tull, Dani',
#   'gender': 'male',
#   'country': 'US',
#   'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#    'type': 'Country',
#    'name': 'United States',
#    'sort-name': 'United States',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': '1f40c6e1-47ba-4e35-996f-fe6ee5840e62',
#    'type': 'City',
#    'name': 'Los Angeles',
#    'sort-name': 'Los Angeles',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'American artist and musician',
#   'ipi-list': ['00448060266', '00448060364', '00448060462', '00448060560'],
#   'isni-list': ['0000000435993276'],
#   'life-span': {'begin': '1966', 'ended': 'false'},
#   'alias-list': [{'sort-name': 'Tull, Daniel Joel',
#     'type': 'Legal name',
#     'alias': 'Daniel Joel Tull'},
#    {'sort-name': 'Tull, Dani', 'type': 'Artist name', 'alias': 'Dani Tull'}]},
#  {'id': '5decf8db-2243-4880-9fc5-ee4219d6bbc4',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Bruce Tull',
#   'sort-name': 'Tull, Bruce',
#   'life-span': {'ended': 'false'}},
#  {'id': 'd1abf243-325c-42eb-8977-db0098d7fdab',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Nils Tull',
#   'sort-name': 'Tull, Nils',
#   'gender': 'male',
#   'country': 'SE',
#   'area': {'id': '23d10872-f5ae-3f0c-bf55-332788a16ecb',
#    'type': 'Country',
#    'name': 'Sweden',
#    'sort-name': 'Sweden',
#    'life-span': {'ended': 'false'}},
#   'life-span': {'begin': '1980', 'ended': 'false'}},
#  {'id': '817c4333-3fce-47d0-83c4-d0090ad5d907',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Dave Tull',
#   'sort-name': 'Tull, Dave',
#   'gender': 'male',
#   'country': 'US',
#   'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#    'type': 'Country',
#    'name': 'United States',
#    'sort-name': 'United States',
#    'life-span': {'ended': 'false'}},
#   'begin-area': {'id': 'f9719692-c39a-4d9c-bf8c-dd4035b09534',
#    'type': 'City',
#    'name': 'Berkeley',
#    'sort-name': 'Berkeley',
#    'life-span': {'ended': 'false'}},
#   'ipi-list': ['00189623625'],
#   'life-span': {'begin': '1963-04-17', 'ended': 'false'},
#   'alias-list': [{'sort-name': 'Tull, David Ferguson',
#     'type': 'Legal name',
#     'alias': 'David Ferguson Tull'}]},
#  {'id': 'f7af4950-7138-41ed-82de-14fa8c751558',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Olle Tull',
#   'sort-name': 'Tull, Olle',
#   'gender': 'male',
#   'country': 'SE',
#   'area': {'id': '23d10872-f5ae-3f0c-bf55-332788a16ecb',
#    'type': 'Country',
#    'name': 'Sweden',
#    'sort-name': 'Sweden',
#    'life-span': {'ended': 'false'}},
#   'life-span': {'ended': 'false'}},
#  {'id': 'a9be6550-0e99-4fd1-a8a3-bdbc95aa6cc6',
#   'ext:score': '32',
#   'name': 'Jérémie Tull',
#   'sort-name': 'Tull, Jérémie',
#   'gender': 'male',
#   'life-span': {'ended': 'false'}},
#  {'id': '1918c282-ffaa-4dd0-a3f1-a2f0c3a650d7',
#   'type': 'Group',
#   'ext:score': '32',
#   'name': 'D’accord',
#   'sort-name': 'D’accord',
#   'country': 'NO',
#   'area': {'id': '6743d351-6f37-3049-9724-5041161fff4d',
#    'type': 'Country',
#    'name': 'Norway',
#    'sort-name': 'Norway',
#    'life-span': {'ended': 'false'}},
#   'disambiguation': 'Norwegian retro-prog inspired by Genesis, Yes, Jethro Tull etc.',
#   'life-span': {'begin': '2008-01-10', 'ended': 'false'},
#   'tag-list': [{'count': '0',
#     'name': 'd accord måge prog rock rossehaug anal bros yes jethro tull rock hard alternative mellotron flute anderson helike stereobrigade genesis flower kings camel caravan progressive rock'}]},
#  {'id': '812c4513-575b-4286-8d0d-9c30038a0076',
#   'type': 'Person',
#   'ext:score': '32',
#   'name': 'Jethro Chaplin',
#   'sort-name': 'Chaplin, Jethro',
#   'gender': 'male',
#   'country': 'GB',
#   'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#    'type': 'Country',
#    'name': 'United Kingdom',
#    'sort-name': 'United Kingdom',
#    'life-span': {'ended': 'false'}},
#   'life-span': {'ended': 'false'},
#   'tag-list': [{'count': '1', 'name': 'world'}]}]

# %%
test_case.keys()
# Out:
# dict_keys(['artist-list', 'artist-count'])

# %%
test_case['artist-count']
# Out:
# 327

# %%
music.search

# %%
music.search_works(artist='Jethro Tull')
# Out:
# {'work-list': [{'id': 'd4daef88-7dee-43dd-bd91-03080fd81358',
#    'ext:score': '100',
#    'title': 'Sketches on a Tudor Psalm',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': 'ea6b4c5f-d8a1-455d-9382-ee0fa577d511',
#       'title': 'Sketches on a Tudor Psalm'},
#      'attributes': []},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': '8a07ac6e-7a41-444b-b8cb-2ff7685e660f',
#       'title': 'Sketches on a Tudor Psalm'},
#      'attributes': []},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '2cdc2d25-8b22-48ba-883a-15802b34e981',
#       'title': 'Sketches on a Tudor Psalm'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '6fdc1445-a02b-49a6-8b3e-9c14f7f03070',
#       'title': 'Sketches on a Tudor Psalm'}}]},
#   {'id': 'fe56227c-7b05-4fd8-a988-1b7f1c145dfa',
#    'type': 'Song',
#    'ext:score': '94',
#    'title': 'New Religion',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': 'edf1d7c7-57b7-42a0-8b24-5cf6b4ba7a4c',
#       'name': 'Jethro Adlington',
#       'sort-name': 'Adlington, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '2df1b8bd-8d73-465a-ab7a-faa90d8aa645',
#       'title': 'New Religion'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': '4a2d1534-d759-4dac-a9e2-b3a0fae89167',
#       'title': 'New Religion'},
#      'attributes': []},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': 'b648e72c-324b-4fb1-a853-e13c67cb30b2',
#       'title': 'New Religion'},
#      'attributes': []}]},
#   {'id': '02d0554e-4e29-44dc-9bda-3b6bd68d13bb',
#    'ext:score': '94',
#    'title': 'Variations on an Advent Hymn: Variation 2',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '20993beb-8d2c-4e38-962b-c6d08a3bb6da',
#       'title': 'Variants on an Advent Hymn: Variation II'}}]},
#   {'id': 'dea154a7-0773-4b7d-b4e6-c48a553359a4',
#    'ext:score': '94',
#    'title': 'Variations on an Advent Hymn: Variation 4',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'a26a92bc-db31-4bf1-8feb-3fa29025609f',
#       'title': 'Variants on an Advent Hymn: Variation IV'}}]},
#   {'id': '34170ff0-a325-44aa-966e-768ee1fa82e1',
#    'ext:score': '94',
#    'title': 'Variations on an Advent Hymn: Theme',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '42b3200e-c133-4640-9c93-7c269d17022b',
#       'title': 'Variants on an Advent Hymn: Theme and Variation I'}}]},
#   {'id': 'fdfa1cda-4312-4c64-b891-05c79e736bfc',
#    'ext:score': '94',
#    'title': 'Variations on an Advent Hymn: Variation 3',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '81ef7122-e8c9-44a4-a022-8ab18a437211',
#       'title': 'Variants on an Advent Hymn: Variation III'}}]},
#   {'id': 'b4ce0f97-0f23-4669-b5f7-3e4ac65b719a',
#    'ext:score': '94',
#    'title': 'Accolade',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'd2583d2e-42e3-4af3-9454-40ffb1e52e3b',
#       'title': 'Accolade'}}]},
#   {'id': '1d1af87f-5c8d-4bb6-9cc3-a0e72f193444',
#    'ext:score': '94',
#    'title': 'Variations on an Advent Hymn: Variation 1',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '42b3200e-c133-4640-9c93-7c269d17022b',
#       'title': 'Variants on an Advent Hymn: Theme and Variation I'}}]},
#   {'id': '04b475e5-d970-4936-a602-143e04eb7d52',
#    'ext:score': '94',
#    'title': 'Concerto Grosso',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '28e53c7d-e126-4d75-b9c7-2d42ab8aac08',
#       'title': 'Concerto Grosso'}}]},
#   {'id': '9aa1dc50-a4f8-4d56-816f-ad96ca8b3bed',
#    'type': 'Song',
#    'ext:score': '90',
#    'title': 'Blood on the Wall',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': 'edf1d7c7-57b7-42a0-8b24-5cf6b4ba7a4c',
#       'name': 'Jethro Adlington',
#       'sort-name': 'Adlington, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '43bae99b-62e1-46a0-93fe-6443f766570b',
#       'title': 'Blood on the Wall'}}]},
#   {'id': 'b45c304a-7847-44d3-8125-7bcacee2e629',
#    'type': 'Song',
#    'ext:score': '90',
#    'title': 'Arabian Daze',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': 'edf1d7c7-57b7-42a0-8b24-5cf6b4ba7a4c',
#       'name': 'Jethro Adlington',
#       'sort-name': 'Adlington, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '66583ec9-8d5a-48a2-aead-da79d62e7968',
#       'title': 'Arabian Daze'}}]},
#   {'id': '9ebb0655-ac59-47b1-a486-87c1dae21169',
#    'type': 'Song',
#    'ext:score': '90',
#    'title': 'Number Seven',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': 'edf1d7c7-57b7-42a0-8b24-5cf6b4ba7a4c',
#       'name': 'Jethro Adlington',
#       'sort-name': 'Adlington, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'd155e962-924d-465b-90b8-7349cebec0e3',
#       'title': 'Number Seven'}}]},
#   {'id': '1457834c-1c8a-4cdc-bfc4-49df54138d92',
#    'type': 'Poem',
#    'ext:score': '90',
#    'title': "The Christmas of '84",
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '82d70de4-ddf9-4c92-97df-1bb66b16c27c',
#       'name': 'Jethro Platts',
#       'sort-name': 'Platts, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '7810d4fa-d093-4b5e-89f0-ad2878267c28',
#       'title': 'The Christmas of ’84'}}]},
#   {'id': 'bd8272fe-1bfb-406a-a276-4adec278e99b',
#    'ext:score': '90',
#    'title': '’Cept Old Bill',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}},
#     {'type': 'lyricist',
#      'type-id': '3e48faba-ec01-47fd-8e89-30e81161661c',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '4c701ccd-4bad-4951-87ed-278a2ecb07c5',
#       'title': '’Cept Old Bill'}}]},
#   {'id': '2722e7ea-c45c-4ea5-a82e-8e22fea45fda',
#    'ext:score': '90',
#    'title': 'Variations on an Advent Hymn',
#    'language': 'zxx',
#    'artist-relation-list': [{'type': 'composer',
#      'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#      'direction': 'backward',
#      'artist': {'id': '3a611b91-55dc-4a38-97a2-22a8e59bb761',
#       'name': 'Fisher Tull',
#       'sort-name': 'Tull, Fisher'}}]},
#   {'id': '0f637e39-5a26-4b60-b538-0c396cf82223',
#    'type': 'Song',
#    'ext:score': '72',
#    'title': 'Yaller Rose of Texas',
#    'language': 'eng',
#    'disambiguation': 'satirical version',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0cc9cfeb-3ac1-446c-8fc9-79a105415891',
#       'name': 'Henry D. Haynes',
#       'sort-name': 'Haynes, Henry D.'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'c6f886f8-5242-423b-8d86-caab7f245416',
#       'title': 'Yaller Rose of Texas, You All'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '90a87fe3-404f-4f62-86a0-27af48216892',
#       'title': 'Yaller Rose of Texas, You-All'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '1e16ae9f-a3d4-4989-bfe6-6afd4c7d8d39',
#       'title': 'Yaller Rose of Texas, You All'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '6dfd12d0-3c37-46f5-9b7a-143db74bf6ee',
#       'title': 'Yaller Rose of Texas, You All'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'a315b595-94ed-49b6-8ecc-924e0c868453',
#       'title': 'Yaller Rose of Texas'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': 'd0697c32-a101-4c23-af88-fe9311904ccf',
#       'title': 'Yeller Rose of Texas'},
#      'attributes': []}]},
#   {'id': '892417f0-85ae-415f-8a9e-866125664325',
#    'type': 'Song',
#    'ext:score': '71',
#    'title': 'You Could Have Been Someone',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '4e7ee52e-adbb-4410-a338-35d5615136c8',
#       'name': 'Ray Wilson',
#       'sort-name': 'Wilson, Ray',
#       'disambiguation': 'Genesis vocalist for a short time'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'b780c9de-d2bc-4042-930f-16f677a8ef53',
#       'name': 'Jethro Bodean',
#       'sort-name': 'Bodean, Jethro',
#       'disambiguation': 'songwriter and producer'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'bacdfe7f-e92f-44bb-8fba-f4e987576c7e',
#       'title': 'You Could Have Been Someone'}}]},
#   {'id': 'c63648b4-e651-4c2e-9ae7-ccd0aec40029',
#    'type': 'Song',
#    'ext:score': '71',
#    'title': 'Amelia',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '4e7ee52e-adbb-4410-a338-35d5615136c8',
#       'name': 'Ray Wilson',
#       'sort-name': 'Wilson, Ray',
#       'disambiguation': 'Genesis vocalist for a short time'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'b780c9de-d2bc-4042-930f-16f677a8ef53',
#       'name': 'Jethro Bodean',
#       'sort-name': 'Bodean, Jethro',
#       'disambiguation': 'songwriter and producer'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '69435bc9-3ca7-4395-ba19-6acff54fb88b',
#       'title': 'Amelia'}}]},
#   {'id': '375c0439-4b59-4a99-ba02-e6bcc7ded75f',
#    'type': 'Song',
#    'ext:score': '71',
#    'title': 'The Last Laugh',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '4e7ee52e-adbb-4410-a338-35d5615136c8',
#       'name': 'Ray Wilson',
#       'sort-name': 'Wilson, Ray',
#       'disambiguation': 'Genesis vocalist for a short time'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'b780c9de-d2bc-4042-930f-16f677a8ef53',
#       'name': 'Jethro Bodean',
#       'sort-name': 'Bodean, Jethro',
#       'disambiguation': 'songwriter and producer'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'fc7ca950-cf73-4f3f-8909-2c810d2e1251',
#       'title': 'The Last Laugh'}}]},
#   {'id': '96c69dde-57e1-433a-aa14-ec755291e2f1',
#    'type': 'Song',
#    'ext:score': '71',
#    'title': 'I, Like You',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'b780c9de-d2bc-4042-930f-16f677a8ef53',
#       'name': 'Jethro Bodean',
#       'sort-name': 'Bodean, Jethro',
#       'disambiguation': 'songwriter and producer'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '4e7ee52e-adbb-4410-a338-35d5615136c8',
#       'name': 'Ray Wilson',
#       'sort-name': 'Wilson, Ray',
#       'disambiguation': 'Genesis vocalist for a short time'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '180db8ea-9f82-40ce-91ec-86958a1fed32',
#       'title': 'I, Like You'}}]},
#   {'id': 'd0e0c88b-6362-43df-8377-675b2dae2e95',
#    'type': 'Song',
#    'ext:score': '71',
#    'title': 'The Weight of Man',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'b780c9de-d2bc-4042-930f-16f677a8ef53',
#       'name': 'Jethro Bodean',
#       'sort-name': 'Bodean, Jethro',
#       'disambiguation': 'songwriter and producer'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '4e7ee52e-adbb-4410-a338-35d5615136c8',
#       'name': 'Ray Wilson',
#       'sort-name': 'Wilson, Ray',
#       'disambiguation': 'Genesis vocalist for a short time'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'a8771250-8c39-4b0a-881c-727bb5d97889',
#       'title': 'The Weight of Man'}}]},
#   {'id': 'c3002e29-c829-4a7a-825d-77e8a06e35f1',
#    'type': 'Song',
#    'ext:score': '64',
#    'title': 'Fractured Folk Song',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0cc9cfeb-3ac1-446c-8fc9-79a105415891',
#       'name': 'Henry D. Haynes',
#       'sort-name': 'Haynes, Henry D.'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '7f34a2a5-079e-4cb8-8ea8-50a760c6ff7c',
#       'title': 'Country Bear Jamboree'}}]},
#   {'id': '393db2a5-f75d-4c19-badb-554d610e6e12',
#    'type': 'Song',
#    'ext:score': '61',
#    'title': 'I’m Movin’ On No. 2',
#    'language': 'eng',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0cc9cfeb-3ac1-446c-8fc9-79a105415891',
#       'name': 'Henry D. Haynes',
#       'sort-name': 'Haynes, Henry D.'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': 'c328faea-ae26-4988-85f5-e9a8dc322bb1',
#       'name': 'Hank Snow',
#       'sort-name': 'Snow, Hank'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '4a4747cd-8128-4d55-86ee-03cb37d594a3',
#       'title': 'I’m Movin’ On'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': 'b1c3584f-b8c6-47bb-9b0f-e65a2c42c67a',
#       'title': 'I’m Movin’ On'},
#      'attributes': []},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '09d27640-e6e7-47f8-91bb-d003f05dcfc2',
#       'title': "I'm Movin' On"}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'attribute-list': [],
#      'recording': {'id': 'a4c47f5e-c1c8-4911-9acb-ff03dfaf7ed3',
#       'title': 'I’m Movin’ On'},
#      'attributes': []},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'e0710470-4ea2-4423-9782-b364ae955b86',
#       'title': 'I’m Movin’ on No. 2'}}]},
#   {'id': 'fe9c0cca-274c-433a-afbc-40c42cd0522f',
#    'type': 'Song',
#    'ext:score': '57',
#    'title': 'Tennessee Border No. 2',
#    'language': 'eng',
#    'iswc-list': ['T-071.224.226-6'],
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0cc9cfeb-3ac1-446c-8fc9-79a105415891',
#       'name': 'Henry D. Haynes',
#       'sort-name': 'Haynes, Henry D.'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '819ec00e-bbf7-4fd5-848f-97ec38b04bf5',
#       'name': 'Jimmy Work',
#       'sort-name': 'Work, Jimmy',
#       'disambiguation': 'Country music singer and songwriter'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'bd5693ef-0079-4435-a860-eb4155ac603a',
#       'title': 'Tennessee Border No. 2'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': 'c5389e13-8fd3-439a-bc21-2cb30135d6e0',
#       'title': 'Tennessee Border No. 2'}}]},
#   {'id': '6b1796b3-81bf-41b5-9341-559575e88ab2',
#    'type': 'Song',
#    'ext:score': '57',
#    'title': "Baby, It's Cold Outside",
#    'language': 'eng',
#    'disambiguation': 'parody',
#    'artist-relation-list': [{'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0a0688ca-72c2-46d6-a3b9-b297e7dad6dc',
#       'name': 'Frank Loesser',
#       'sort-name': 'Loesser, Frank'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '0cc9cfeb-3ac1-446c-8fc9-79a105415891',
#       'name': 'Henry D. Haynes',
#       'sort-name': 'Haynes, Henry D.'}},
#     {'type': 'writer',
#      'type-id': 'a255bca1-b157-4518-9108-7b147dc3fc68',
#      'direction': 'backward',
#      'artist': {'id': '9974444f-555e-4956-aca8-b3527fa67f24',
#       'name': 'Jethro Burns',
#       'sort-name': 'Burns, Jethro'}}],
#    'recording-relation-list': [{'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '34df9a27-49a3-4a7b-a99e-00c4dc7f79d9',
#       'title': 'Baby, It’s Cold Outside'}},
#     {'type': 'performance',
#      'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#      'direction': 'backward',
#      'recording': {'id': '36a6e78c-f092-4fe5-a043-8c619697111d',
#       'title': "Baby, It's Cold Outside"}}]}],
#  'work-count': 26}

# %%
music.get_release_by_id(id='ece57992-dc2e-4f67-a269-fa43626c1a3d')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:497, in _safe_read(opener, req, body, max_retries, retry_delay_delta)
#     496 else:
# --> 497 	f = opener.open(req)
#     498 return f.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# ResponseError                             Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 music.get_release_by_id(id='ece57992-dc2e-4f67-a269-fa43626c1a3d')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:879, in get_release_by_id(id, includes, release_status, release_type)
#     874 """Get the release with the MusicBrainz `id` as a dict with a 'release' key.
#     875
#     876 *Available includes*: {includes}"""
#     877 params = _check_filter_and_make_params("release", includes,
#     878                                        release_status, release_type)
# --> 879 return _do_mb_query("release", id, includes, params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:728, in _do_mb_query(entity, id, includes, params)
#     726 # Build the endpoint components.
#     727 path = '%s/%s' % (entity, id)
# --> 728 return _mb_request(path, 'GET', auth_required, args=args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:417, in _rate_limit.__call__(self, *args, **kwargs)
#     415     # Call the original function, "paying" for this call.
#     416     self.remaining_requests -= 1.0
# --> 417 return self.fun(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:690, in _mb_request(path, method, auth_required, client_required, args, data, body)
#     686 elif not data and not req.has_header('Content-Length'):
#     687     # Explicitly indicate zero content length if no request data
#     688     # will be sent (avoids HTTP 411 error).
#     689     req.add_header('Content-Length', '0')
# --> 690 resp = _safe_read(opener, req, body)
#     692 return parser_fun(resp)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/musicbrainzngs/musicbrainz.py:503, in _safe_read(opener, req, body, max_retries, retry_delay_delta)
#     500 except compat.HTTPError as exc:
#     501 	if exc.code in (400, 404, 411):
#     502 		# Bad request, not found, etc.
# --> 503 		raise ResponseError(cause=exc)
#     504 	elif exc.code in (503, 502, 500):
#     505 		# Rate limiting, internal overloading...
#     506 		_log.info("HTTP error %i" % exc.code)
#
# ResponseError: caused by: HTTP Error 404: Not Found

# %%
music.browse_release_groups(artist_id='Jethro Tull')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 music.browse_release_groups(artist_id='Jethro Tull')
#
# TypeError: browse_release_groups() got an unexpected keyword argument 'artist_id'

# %%
music.get_artist_by_id(music.search_artists(artist='Steely Dan')['artist-list'][0]['id'])['artist']['area']['name']
# Out:
# 'New York'

# %%
music.browse_release_groups(music.search_artists(artist='Steely Dan')['artist-list'][0]['id'], release_type=["album"])['release-group-list']
# Out:
# [{'id': '9d73a864-2976-3286-b6c1-8aabc7407737',
#   'type': 'Album',
#   'title': 'Can’t Buy a Thrill',
#   'first-release-date': '1972-10',
#   'primary-type': 'Album'},
#  {'id': '33726877-dd41-301b-9f1e-498ebbadc7d8',
#   'type': 'Album',
#   'title': 'Countdown to Ecstasy',
#   'first-release-date': '1973-07',
#   'primary-type': 'Album'},
#  {'id': '5c938587-b4cd-3d6c-9f9e-a87492a2c9de',
#   'type': 'Album',
#   'title': 'Pretzel Logic',
#   'first-release-date': '1974-03-02',
#   'primary-type': 'Album'},
#  {'id': 'a5b292d7-f237-386e-a25e-fa30916544f1',
#   'type': 'Album',
#   'title': 'Katy Lied',
#   'first-release-date': '1975-03',
#   'primary-type': 'Album'},
#  {'id': '586013b7-6cb0-39d4-b3cc-702b665fd830',
#   'type': 'Album',
#   'title': 'The Royal Scam',
#   'first-release-date': '1976-05',
#   'primary-type': 'Album'},
#  {'id': '8588c5a5-b491-37a4-8d51-2227346a072e',
#   'type': 'Album',
#   'title': 'Aja',
#   'first-release-date': '1977-09-23',
#   'primary-type': 'Album'},
#  {'id': '953426ac-0f78-3845-a968-87140cb6db17',
#   'type': 'Album',
#   'title': 'Gaucho',
#   'first-release-date': '1980-11-21',
#   'primary-type': 'Album'},
#  {'id': 'd8b5fa5e-0bbd-3764-829c-7f340648ce59',
#   'type': 'Album',
#   'title': 'Two Against Nature',
#   'first-release-date': '2000-02-29',
#   'primary-type': 'Album'},
#  {'id': 'a7f2a278-6e34-3bf4-9fb5-2fc3bf074236',
#   'type': 'Album',
#   'title': 'Everything Must Go',
#   'first-release-date': '2003-06-09',
#   'primary-type': 'Album'},
#  {'id': '85ddf3ab-bb99-4668-a0b6-7c6780314c89',
#   'type': 'Compilation',
#   'title': 'Steely Dan',
#   'first-release-date': '1978-06',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '82d1e6c2-13e9-3644-a018-411802b784dd',
#   'type': 'Compilation',
#   'title': 'Greatest Hits',
#   'first-release-date': '1978',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': 'a943bd62-6a0d-4c78-897b-197023ac58b5',
#   'type': 'Compilation',
#   'title': 'The Very Best of Steely Dan',
#   'first-release-date': '1979',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': 'ec78b08e-4907-437a-ac01-4da916105726',
#   'type': 'Compilation',
#   'title': 'Countdown to Ecstasy / Can’t Buy a Thrill',
#   'first-release-date': '1982',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': 'b87ed773-086b-3b52-b34f-657887a9136f',
#   'type': 'Compilation',
#   'title': 'Gold',
#   'first-release-date': '1982',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '44ad3c56-e59a-454c-9aa1-909266434735',
#   'type': 'Compilation',
#   'title': 'Katy Lied / The Royal Scam',
#   'first-release-date': '1982',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': 'bb76cdff-2041-3e5f-86c3-2525300a2a3d',
#   'type': 'Compilation',
#   'title': 'A Decade of Steely Dan',
#   'first-release-date': '1985',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '3ee91ddd-abd0-4cdd-a64d-2cc21f90a61d',
#   'type': 'Compilation',
#   'title': 'Berry Town',
#   'first-release-date': '1985',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '05782763-712d-3d23-96a9-035b6238f857',
#   'type': 'Compilation',
#   'title': 'Sun Mountain',
#   'first-release-date': '1985',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '62acfb14-d268-4d5a-af82-0af8c430b22f',
#   'type': 'Compilation',
#   'title': 'The Very Best of Steely Dan: Reelin’ In the Years',
#   'first-release-date': '1985',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': 'd2e1680a-68c2-3934-b3a8-88782f7c5c2b',
#   'type': 'Compilation',
#   'title': 'Old Regime',
#   'first-release-date': '1987',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '85e7ce76-d90c-38e5-972f-1bc83da21d06',
#   'type': 'Compilation',
#   'title': 'The Very Best of Steely Dan',
#   'first-release-date': '1987',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '1210af07-f682-4c0f-94ae-c420aaa79d97',
#   'type': 'Compilation',
#   'title': 'Stone Piano',
#   'first-release-date': '1988',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '544b6d19-778c-38b3-ad73-ef0553d9d33e',
#   'type': 'Compilation',
#   'title': 'Citizen Steely Dan: 1972–1980',
#   'first-release-date': '1993',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '151dbb7f-655b-328e-9395-a2b8b2c3a4f2',
#   'type': 'Compilation',
#   'title': 'Remastered: The Best of Steely Dan (Then and Now)',
#   'first-release-date': '1993',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']},
#  {'id': '2be1db1b-60f4-480e-9ca1-b2a14f66e2b2',
#   'type': 'Compilation',
#   'title': 'Becker & Fagan From Steely Dan Collection',
#   'first-release-date': '1994',
#   'primary-type': 'Album',
#   'secondary-type-list': ['Compilation']}]

# %%
test_case[1]
# Out:
# {'id': '33726877-dd41-301b-9f1e-498ebbadc7d8',
#  'type': 'Album',
#  'title': 'Countdown to Ecstasy',
#  'first-release-date': '1973-07',
#  'primary-type': 'Album'}

# %%
test_case = music.browse_release_groups(music.search_artists(artist='Steely Dan')['artist-list'][0]['id'], release_type=["album"])['release-group-list']
album_name = []
release_date = []

for album in test_case:
    album_name.append(album['title'])
    release_date.append(album['first-release-date'])

# %%
pd.DataFrame({
    'album':album_name,
    'date':release_date
}).sort_values('date')
# Out:
#                                                 album        date
# 0                                  Can’t Buy a Thrill     1972-10
# 1                                Countdown to Ecstasy     1973-07
# 2                                       Pretzel Logic  1974-03-02
# 3                                           Katy Lied     1975-03
# 4                                      The Royal Scam     1976-05
# 5                                                 Aja  1977-09-23
# 10                                      Greatest Hits        1978
# 9                                          Steely Dan     1978-06
# 11                        The Very Best of Steely Dan        1979
# 6                                              Gaucho  1980-11-21
# 14                         Katy Lied / The Royal Scam        1982
# 13                                               Gold        1982
# 12          Countdown to Ecstasy / Can’t Buy a Thrill        1982
# 15                             A Decade of Steely Dan        1985
# 16                                         Berry Town        1985
# 17                                       Sun Mountain        1985
# 18  The Very Best of Steely Dan: Reelin’ In the Years        1985
# 19                                         Old Regime        1987
# 20                        The Very Best of Steely Dan        1987
# 21                                        Stone Piano        1988
# 22                      Citizen Steely Dan: 1972–1980        1993
# 23  Remastered: The Best of Steely Dan (Then and Now)        1993
# 24          Becker & Fagan From Steely Dan Collection        1994
# 7                                  Two Against Nature  2000-02-29
# 8                                  Everything Must Go  2003-06-09

# %%
music.search_artists(artist='Steely Dan')['artist-list'][0]['life-span']['begin']
# Out:
# '1972'

# %%
def create_cleaned_artist(artist_name):
    try:
        artist_high_level = music.get_artist_by_id(music.search_artists(artist= artist_name)['artist-list'][0]['id'])['artist']
        first_albums = music.browse_release_groups(music.search_artists(artist=artist_name)['artist-list'][0]['id'], release_type=["album"])['release-group-list']
        start_band_date = music.search_artists(artist=artist_name)['artist-list'][0]['life-span']['begin']

        name = artist_name
        begin_year = int(start_band_date)
        area = artist_high_level['area']['name']
        albums = []

        album_name = []
        release_date = []

        for album in first_albums:
            album_name.append(album['title'])
            release_date.append(album['first-release-date'])

        date_name_frame = pd.DataFrame({'albums':album_name, 'date':release_date}).sort_values('date')
        first_four_years = date_name_frame['date'].apply(lambda x: pd.Timestamp(x).date()).values[:4]

        final_dict = {
            'name':artist_name,
            'form_date':begin_year,
            'location':area,
            'release_1':first_four_years[0],
            'release_2':first_four_years[1],
            'release_3':first_four_years[2],
            'release_4':first_four_years[3]
        }

        return pd.DataFrame(final_dict,index=[0])
    except:
        return None

# %%
data_points = []

for artist in rock_bands:
    print(artist)
    data_points.append(create_cleaned_artist(artist))
    time.sleep(3)
# Out:
# AC/DC
# Aerosmith
# Alice Cooper
# Allman Brothers Band
# Bad Company
# Black Sabbath
# Blue Öyster Cult
# Boston
# Cheap Trick
# Creedence Clearwater Revival
# Deep Purple
# Def Leppard
# Derek and the Dominos
# Eagles
# Fleetwood Mac
# Foreigner
# Genesis
# Grateful Dead
# Heart
# Iron Maiden
# Jethro Tull
# Judas Priest
# Kansas
# KISS
# Led Zeppelin
# Lynyrd Skynyrd
# Motörhead
# Nazareth
# Pink Floyd
# Queen
# Rainbow
# REO Speedwagon
# Rush
# Santana
# Scorpions
# Steely Dan
# Styx
# Ted Nugent
# The Band
# The Doors
# The Police
# The Rolling Stones
# The Who
# Thin Lizzy
# Tom Petty and the Heartbreakers
# Triumph
# UFO
# Uriah Heep
# Van Halen
# Yes
# ZZ Top
# Bon Jovi
# Bruce Springsteen
# Dire Straits
# Guns N' Roses
# INXS
# Journey
# Metallica
# Nirvana
# Pearl Jam
# Poison
# R.E.M.
# Red Hot Chili Peppers
# Roxy Music
# Soundgarden
# The Cure
# The Smiths
# U2
# Whitesnake
# Winger
# Warrant
# 10cc
# Argent
# Asia
# Bachman-Turner Overdrive
# Badfinger
# Big Star
# Blind Faith
# The Byrds
# Camel
# Can
# Caravan
# Cheap Trick
# Chicago
# Colosseum
# Cream
# Crosby, Stills, Nash & Young
# David Bowie
# Devo
# Doobie Brothers
# Electric Light Orchestra
# Emerson, Lake & Palmer
# Fairport Convention
# Focus
# Free
# Gentle Giant
# Hawkwind
# Humble Pie
# King Crimson
# Little Feat
# Love
# Manfred Mann's Earth Band
# MC5
# Mountain
# Mott the Hoople
# New York Dolls
# Nick Cave and the Bad Seeds
# Pavement
# Pixies
# Procol Harum
# Public Image Ltd.
# Renaissance
# Roxy Music
# Slade
# Small Faces
# Spinal Tap
# Steppenwolf
# The Animals
# The Beach Boys
# The Clash
# The Kinks
# The Monkees
# The Move
# The Troggs
# Traffic
# Velvet Underground
# Wings
# XTC
# Yes
# Zombies
# ZZ Top
# Anthrax
# Black Crowes
# Blondie
# Bush
# Counting Crows
# Dinosaur Jr.
# Faith No More
# Fugazi
# Green Day
# Hole
# Jane's Addiction
# Live
# Meat Puppets
# Nine Inch Nails
# Oasis
# Offspring
# Pixies
# Pulp
# Radiohead
# Rage Against the Machine
# Screaming Trees
# Sex Pistols
# Smashing Pumpkins
# Stone Temple Pilots
# Suicidal Tendencies
# T. Rex
# Talking Heads
# The B-52's
# The Breeders
# The Jam
# The Pretenders
# The Replacements
# The Stranglers
# The Verve
# They Might Be Giants
# Tool
# Violent Femmes
# Weezer
# Wilco
# Big Country
# Blue Cheer
# The Cars
# Clash
# Damn Yankees
# Dream Theater
# Extreme
# Fastway
# Goo Goo Dolls
# Hanoi Rocks
# Helmet
# Hootie & the Blowfish
# Hüsker Dü
# Iron Butterfly
# L.A. Guns
# Living Colour
# Love and Rockets
# Marillion
# Meat Loaf
# Midnight Oil
# Ministry
# Mr. Big
# Night Ranger
# The Outlaws
# Pat Benatar
# Peter Frampton
# Primus
# Queensrÿche
# Saga
# Savatage
# Sepultura
# Silverchair
# Skid Row
# Slayer
# Sonic Youth
# Spandau Ballet
# Status Quo
# Stryper
# Sugar
# Tesla
# The Cult
# The Fabulous Thunderbirds
# The Guess Who
# The Lemonheads
# The Meat Puppets
# The Moody Blues
# The Outfield
# The Pogues
# The Scorpions
# The Stone Roses
# The Traveling Wilburys
# The Tubes
# The Zombies
# Third Eye Blind
# Toto
# Tygers of Pan Tang
# Ugly Kid Joe
# Van Der Graaf Generator
# W.A.S.P.
# War
# Ween
# White Lion
# Widespread Panic
# X
# Yardbirds
# Yngwie Malmsteen
# Zebra
# Ziggy Marley and the Melody Makers

# %%
test = pd.concat([record for record in data_points if record is not None])

# %%
test = test.dropna()

# %%
for row in test.:
    print(row)
# Out:
# ['Aerosmith' 1970 'United States' datetime.date(1973, 1, 5)
#  datetime.date(1974, 3, 1) datetime.date(1975, 4, 8)
#  datetime.date(1976, 5, 14)]
# ['Blue Öyster Cult' 1967 'United States' datetime.date(1972, 1, 16)
#  datetime.date(1973, 1, 1) datetime.date(1974, 4, 1)
#  datetime.date(1976, 5, 21)]
# ['Cheap Trick' 1973 'United States' datetime.date(1977, 1, 1)
#  datetime.date(1977, 9, 1) datetime.date(1978, 1, 1)
#  datetime.date(1978, 1, 1)]
# ['Creedence Clearwater Revival' 1959 'United States'
#  datetime.date(1968, 7, 5) datetime.date(1969, 1, 5)
#  datetime.date(1969, 8, 3) datetime.date(1969, 11, 2)]
# ['Deep Purple' 1968 'United Kingdom' datetime.date(1968, 7, 17)
#  datetime.date(1968, 10, 1) datetime.date(1969, 1, 1)
#  datetime.date(1969, 6, 21)]
# ['Def Leppard' 1977 'United Kingdom' datetime.date(1980, 3, 14)
#  datetime.date(1981, 7, 11) datetime.date(1983, 1, 20)
#  datetime.date(1987, 8, 3)]
# ['Eagles' 1971 'United States' datetime.date(1972, 6, 1)
#  datetime.date(1973, 4, 17) datetime.date(1974, 3, 22)
#  datetime.date(1975, 6, 10)]
# ['Foreigner' 1976 'United States' datetime.date(1977, 3, 8)
#  datetime.date(1978, 1, 1) datetime.date(1979, 1, 1)
#  datetime.date(1981, 6, 29)]
# ['Genesis' 1967 'United Kingdom' datetime.date(1969, 3, 7)
#  datetime.date(1970, 10, 1) datetime.date(1971, 11, 12)
#  datetime.date(1972, 10, 1)]
# ['Grateful Dead' 1965 'United States' datetime.date(1967, 3, 17)
#  datetime.date(1968, 7, 18) datetime.date(1969, 6, 20)
#  datetime.date(1970, 6, 14)]
# ['Heart' 1973 'United States' datetime.date(1975, 9, 1)
#  datetime.date(1977, 4, 19) datetime.date(1977, 5, 15)
#  datetime.date(1978, 10, 7)]
# ['Judas Priest' 1969 'United Kingdom' datetime.date(1974, 8, 1)
#  datetime.date(1976, 1, 1) datetime.date(1977, 4, 8)
#  datetime.date(1978, 2, 10)]
# ['Kansas' 1973 'United States' datetime.date(1974, 1, 1)
#  datetime.date(1975, 3, 1) datetime.date(1975, 10, 1)
#  datetime.date(1976, 10, 1)]
# ['Led Zeppelin' 1968 'United Kingdom' datetime.date(1969, 1, 12)
#  datetime.date(1969, 10, 22) datetime.date(1970, 10, 5)
#  datetime.date(1971, 11, 8)]
# ['Lynyrd Skynyrd' 1964 'United States' datetime.date(1973, 8, 13)
#  datetime.date(1974, 4, 15) datetime.date(1975, 3, 24)
#  datetime.date(1976, 2, 2)]
# ['Nazareth' 1968 'United Kingdom' datetime.date(1971, 1, 1)
#  datetime.date(1972, 1, 1) datetime.date(1973, 1, 1)
#  datetime.date(1973, 1, 1)]
# ['Pink Floyd' 1965 'England' datetime.date(1967, 7, 7)
#  datetime.date(1968, 6, 29) datetime.date(1969, 10, 25)
#  datetime.date(1970, 1, 1)]
# ['Rainbow' 1974 'United Kingdom' datetime.date(1975, 1, 1)
#  datetime.date(1976, 6, 21) datetime.date(1978, 4, 14)
#  datetime.date(1979, 1, 1)]
# ['REO Speedwagon' 1967 'United States' datetime.date(1971, 10, 1)
#  datetime.date(1972, 1, 1) datetime.date(1973, 1, 1)
#  datetime.date(1974, 12, 1)]
# ['Santana' 1966 'United States' datetime.date(1969, 8, 30)
#  datetime.date(1970, 11, 1) datetime.date(1971, 9, 1)
#  datetime.date(1972, 10, 1)]
# ['Scorpions' 1965 'Germany' datetime.date(1972, 1, 1)
#  datetime.date(1974, 1, 1) datetime.date(1975, 1, 1)
#  datetime.date(1976, 1, 1)]
# ['Steely Dan' 1972 'New York' datetime.date(1972, 10, 1)
#  datetime.date(1973, 7, 1) datetime.date(1974, 3, 2)
#  datetime.date(1975, 3, 1)]
# ['Styx' 1970 'United States' datetime.date(1972, 8, 31)
#  datetime.date(1973, 7, 1) datetime.date(1973, 10, 1)
#  datetime.date(1974, 11, 8)]
# ['The Rolling Stones' 1962 'United Kingdom' datetime.date(1964, 4, 17)
#  datetime.date(1964, 10, 24) datetime.date(1965, 1, 15)
#  datetime.date(1965, 2, 13)]
# ['Thin Lizzy' 1969 'Ireland' datetime.date(1971, 4, 1)
#  datetime.date(1972, 3, 10) datetime.date(1973, 1, 1)
#  datetime.date(1974, 1, 1)]
# ['Tom Petty and the Heartbreakers' 1976 'United States'
#  datetime.date(1976, 11, 9) datetime.date(1978, 5, 2)
#  datetime.date(1979, 10, 19) datetime.date(1981, 5, 5)]
# ['Triumph' 1975 'Canada' datetime.date(1976, 10, 13)
#  datetime.date(1977, 11, 3) datetime.date(1979, 7, 21)
#  datetime.date(1980, 3, 25)]
# ['UFO' 1969 'United Kingdom' datetime.date(1970, 10, 1)
#  datetime.date(1971, 10, 1) datetime.date(1973, 1, 1)
#  datetime.date(1974, 5, 1)]
# ['Uriah Heep' 1970 'United Kingdom' datetime.date(1970, 6, 1)
#  datetime.date(1971, 2, 1) datetime.date(1971, 10, 1)
#  datetime.date(1972, 5, 1)]
# ['Yes' 1968 'United Kingdom' datetime.date(1969, 7, 25)
#  datetime.date(1970, 7, 24) datetime.date(1971, 1, 29)
#  datetime.date(1971, 11, 12)]
# ['ZZ Top' 1969 'United States' datetime.date(1970, 1, 1)
#  datetime.date(1972, 4, 4) datetime.date(1973, 7, 26)
#  datetime.date(1975, 4, 18)]
# ['Bon Jovi' 1983 'United States' datetime.date(1984, 1, 23)
#  datetime.date(1985, 1, 1) datetime.date(1985, 6, 5)
#  datetime.date(1986, 8, 10)]
# ['Dire Straits' 1977 'United Kingdom' datetime.date(1978, 6, 2)
#  datetime.date(1979, 4, 1) datetime.date(1980, 1, 1)
#  datetime.date(1982, 9, 20)]
# ['Journey' 1973 'United States' datetime.date(1975, 4, 1)
#  datetime.date(1976, 1, 1) datetime.date(1977, 1, 1)
#  datetime.date(1978, 1, 1)]
# ['Nirvana' 1987 'United States' datetime.date(1989, 6, 1)
#  datetime.date(1991, 9, 24) datetime.date(1992, 1, 1)
#  datetime.date(1992, 1, 1)]
# ['Pearl Jam' 1990 'United States' datetime.date(1991, 2, 8)
#  datetime.date(1991, 2, 11) datetime.date(1991, 8, 27)
#  datetime.date(1991, 11, 14)]
# ['Red Hot Chili Peppers' 1983 'United States' datetime.date(1984, 8, 10)
#  datetime.date(1985, 8, 16) datetime.date(1987, 9, 29)
#  datetime.date(1989, 8, 22)]
# ['Roxy Music' 1971 'United Kingdom' datetime.date(1972, 1, 1)
#  datetime.date(1972, 6, 16) datetime.date(1973, 3, 23)
#  datetime.date(1973, 11, 1)]
# ['Soundgarden' 1984 'United States' datetime.date(1988, 10, 25)
#  datetime.date(1989, 9, 5) datetime.date(1990, 6, 8)
#  datetime.date(1991, 10, 8)]
# ['The Cure' 1977 'United Kingdom' datetime.date(1979, 5, 8)
#  datetime.date(1980, 2, 5) datetime.date(1980, 4, 22)
#  datetime.date(1981, 1, 1)]
# ['U2' 1976 'Ireland' datetime.date(1980, 10, 20)
#  datetime.date(1981, 10, 12) datetime.date(1983, 2, 28)
#  datetime.date(1984, 10, 1)]
# ['Whitesnake' 1978 'United Kingdom' datetime.date(1978, 1, 1)
#  datetime.date(1979, 1, 1) datetime.date(1980, 1, 1)
#  datetime.date(1981, 1, 1)]
# ['10cc' 1972 'United Kingdom' datetime.date(1973, 9, 1)
#  datetime.date(1974, 5, 1) datetime.date(1975, 1, 1)
#  datetime.date(1975, 3, 11)]
# ['Argent' 1969 'United Kingdom' datetime.date(1969, 1, 1)
#  datetime.date(1970, 1, 1) datetime.date(1972, 4, 1)
#  datetime.date(1973, 3, 1)]
# ['Asia' 1981 'United Kingdom' datetime.date(1982, 3, 18)
#  datetime.date(1983, 7, 26) datetime.date(1985, 12, 5)
#  datetime.date(1990, 9, 25)]
# ['Bachman-Turner Overdrive' 1970 'Canada' datetime.date(1973, 5, 17)
#  datetime.date(1973, 12, 1) datetime.date(1974, 1, 1)
#  datetime.date(1975, 1, 1)]
# ['Badfinger' 1969 'United Kingdom' datetime.date(1970, 1, 9)
#  datetime.date(1970, 11, 9) datetime.date(1971, 12, 13)
#  datetime.date(1973, 11, 26)]
# ['Big Star' 1971 'Memphis' datetime.date(1972, 1, 1)
#  datetime.date(1974, 1, 1) datetime.date(1978, 1, 1)
#  datetime.date(1987, 1, 1)]
# ['The Byrds' 1964 'United States' datetime.date(1965, 6, 21)
#  datetime.date(1965, 12, 6) datetime.date(1966, 7, 18)
#  datetime.date(1967, 1, 1)]
# ['Camel' 1971 'United Kingdom' datetime.date(1973, 2, 1)
#  datetime.date(1974, 3, 1) datetime.date(1975, 4, 1)
#  datetime.date(1976, 3, 26)]
# ['Can' 1968 'Germany' datetime.date(1969, 8, 1) datetime.date(1970, 1, 1)
#  datetime.date(1971, 1, 1) datetime.date(1972, 11, 1)]
# ['Cheap Trick' 1973 'United States' datetime.date(1977, 1, 1)
#  datetime.date(1977, 9, 1) datetime.date(1978, 1, 1)
#  datetime.date(1978, 1, 1)]
# ['Chicago' 1967 'United States' datetime.date(1969, 1, 1)
#  datetime.date(1970, 1, 1) datetime.date(1971, 1, 1)
#  datetime.date(1972, 7, 10)]
# ['Colosseum' 1968 'United Kingdom' datetime.date(1969, 3, 1)
#  datetime.date(1969, 11, 7) datetime.date(1970, 1, 1)
#  datetime.date(1970, 11, 1)]
# ['Devo' 1972 'United States' datetime.date(1978, 7, 1)
#  datetime.date(1979, 6, 7) datetime.date(1980, 7, 1)
#  datetime.date(1981, 8, 1)]
# ['Doobie Brothers' 1970 'United States' datetime.date(1971, 4, 30)
#  datetime.date(1972, 7, 1) datetime.date(1973, 3, 2)
#  datetime.date(1974, 1, 1)]
# ['Electric Light Orchestra' 1970 'United Kingdom'
#  datetime.date(1971, 12, 3) datetime.date(1973, 3, 2)
#  datetime.date(1973, 11, 1) datetime.date(1974, 9, 1)]
# ['Emerson, Lake & Palmer' 1970 'United Kingdom' datetime.date(1970, 11, 1)
#  datetime.date(1971, 6, 14) datetime.date(1972, 7, 6)
#  datetime.date(1973, 12, 1)]
# ['Fairport Convention' 1967 'United Kingdom' datetime.date(1968, 6, 1)
#  datetime.date(1969, 1, 1) datetime.date(1969, 7, 1)
#  datetime.date(1969, 12, 1)]
# ['Focus' 1969 'Netherlands' datetime.date(1970, 1, 1)
#  datetime.date(1971, 10, 1) datetime.date(1972, 11, 1)
#  datetime.date(1973, 1, 1)]
# ['Free' 1968 'United Kingdom' datetime.date(1969, 3, 14)
#  datetime.date(1969, 10, 1) datetime.date(1970, 6, 16)
#  datetime.date(1970, 12, 1)]
# ['Humble Pie' 1969 'United Kingdom' datetime.date(1969, 1, 1)
#  datetime.date(1969, 1, 1) datetime.date(1970, 7, 1)
#  datetime.date(1971, 3, 1)]
# ['Little Feat' 1969 'United States' datetime.date(1971, 1, 1)
#  datetime.date(1972, 5, 1) datetime.date(1973, 2, 1)
#  datetime.date(1974, 9, 1)]
# ['Love' 1965 'United States' datetime.date(1966, 4, 1)
#  datetime.date(1966, 11, 1) datetime.date(1967, 11, 1)
#  datetime.date(1969, 1, 1)]
# ["Manfred Mann's Earth Band" 1971 'United Kingdom'
#  datetime.date(1972, 1, 1) datetime.date(1972, 9, 29)
#  datetime.date(1973, 6, 15) datetime.date(1973, 11, 30)]
# ['Mountain' 1991 'United States' datetime.date(1991, 1, 1)
#  datetime.date(1992, 1, 1) datetime.date(1993, 1, 1)
#  datetime.date(1993, 1, 1)]
# ['Mott the Hoople' 1969 'United Kingdom' datetime.date(1969, 11, 1)
#  datetime.date(1970, 9, 1) datetime.date(1971, 3, 1)
#  datetime.date(1971, 11, 1)]
# ['Nick Cave and the Bad Seeds' 1983 'Australia' datetime.date(1984, 6, 1)
#  datetime.date(1985, 6, 3) datetime.date(1986, 8, 18)
#  datetime.date(1986, 11, 3)]
# ['Pixies' 1986 'United States' datetime.date(1988, 3, 21)
#  datetime.date(1988, 3, 21) datetime.date(1989, 4, 17)
#  datetime.date(1990, 8, 13)]
# ['Procol Harum' 1967 'United Kingdom' datetime.date(1967, 9, 1)
#  datetime.date(1968, 9, 1) datetime.date(1969, 3, 1)
#  datetime.date(1970, 1, 1)]
# ['Public Image Ltd.' 1978 'United Kingdom' datetime.date(1978, 12, 8)
#  datetime.date(1979, 11, 1) datetime.date(1980, 11, 14)
#  datetime.date(1981, 5, 18)]
# ['Renaissance' 1969 'United Kingdom' datetime.date(1969, 12, 1)
#  datetime.date(1971, 1, 1) datetime.date(1972, 10, 1)
#  datetime.date(1973, 10, 1)]
# ['Roxy Music' 1971 'United Kingdom' datetime.date(1972, 1, 1)
#  datetime.date(1972, 6, 16) datetime.date(1973, 3, 23)
#  datetime.date(1973, 11, 1)]
# ['Slade' 1966 'United Kingdom' datetime.date(1969, 5, 9)
#  datetime.date(1970, 1, 1) datetime.date(1972, 1, 1)
#  datetime.date(1972, 12, 1)]
# ['Small Faces' 1965 'United Kingdom' datetime.date(1966, 5, 1)
#  datetime.date(1967, 6, 1) datetime.date(1967, 6, 1)
#  datetime.date(1967, 12, 1)]
# ['Steppenwolf' 1961 'United States' datetime.date(1968, 1, 29)
#  datetime.date(1968, 10, 1) datetime.date(1969, 1, 1)
#  datetime.date(1969, 3, 1)]
# ['The Animals' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['The Beach Boys' 1961 'United States' datetime.date(1962, 10, 1)
#  datetime.date(1963, 3, 25) datetime.date(1963, 9, 23)
#  datetime.date(1963, 10, 21)]
# ['The Clash' 1976 'United Kingdom' datetime.date(1977, 4, 8)
#  datetime.date(1978, 11, 10) datetime.date(1979, 12, 14)
#  datetime.date(1980, 1, 1)]
# ['The Kinks' 1964 'United Kingdom' datetime.date(1964, 10, 2)
#  datetime.date(1965, 3, 1) datetime.date(1965, 3, 5)
#  datetime.date(1965, 11, 1)]
# ['The Monkees' 1966 'United States' datetime.date(1966, 10, 10)
#  datetime.date(1967, 1, 10) datetime.date(1967, 5, 20)
#  datetime.date(1967, 11, 1)]
# ['The Move' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['Velvet Underground' 1964 'United States' datetime.date(1967, 3, 1)
#  datetime.date(1968, 1, 30) datetime.date(1969, 3, 1)
#  datetime.date(1970, 9, 1)]
# ['Wings' 1971 'United Kingdom' datetime.date(1971, 12, 7)
#  datetime.date(1973, 5, 4) datetime.date(1973, 12, 5)
#  datetime.date(1975, 5, 30)]
# ['XTC' 1976 'United Kingdom' datetime.date(1978, 1, 20)
#  datetime.date(1978, 10, 6) datetime.date(1979, 8, 17)
#  datetime.date(1980, 9, 12)]
# ['Yes' 1968 'United Kingdom' datetime.date(1969, 7, 25)
#  datetime.date(1970, 7, 24) datetime.date(1971, 1, 29)
#  datetime.date(1971, 11, 12)]
# ['Zombies' 1961 'United Kingdom' datetime.date(1965, 1, 1)
#  datetime.date(1965, 1, 1) datetime.date(1966, 1, 1)
#  datetime.date(1968, 4, 19)]
# ['ZZ Top' 1969 'United States' datetime.date(1970, 1, 1)
#  datetime.date(1972, 4, 4) datetime.date(1973, 7, 26)
#  datetime.date(1975, 4, 18)]
# ['Anthrax' 1981 'United States' datetime.date(1984, 1, 6)
#  datetime.date(1985, 10, 30) datetime.date(1987, 3, 22)
#  datetime.date(1988, 9, 18)]
# ['Black Crowes' 1989 'United States' datetime.date(1990, 1, 1)
#  datetime.date(1990, 1, 24) datetime.date(1992, 5, 11)
#  datetime.date(1993, 1, 1)]
# ['Blondie' 1974 'United States' datetime.date(1976, 1, 1)
#  datetime.date(1977, 1, 1) datetime.date(1978, 9, 23)
#  datetime.date(1979, 9, 28)]
# ['Dinosaur Jr.' 1984 'United States' datetime.date(1985, 7, 5)
#  datetime.date(1987, 7, 1) datetime.date(1988, 10, 31)
#  datetime.date(1991, 1, 1)]
# ['Green Day' 1989 'United States' datetime.date(1990, 1, 1)
#  datetime.date(1991, 4, 19) datetime.date(1991, 12, 17)
#  datetime.date(1994, 1, 28)]
# ['Nine Inch Nails' 1988 'United States' datetime.date(1989, 10, 20)
#  datetime.date(1994, 1, 1) datetime.date(1994, 1, 1)
#  datetime.date(1994, 3, 8)]
# ['Oasis' 1991 'United Kingdom' datetime.date(1993, 1, 1)
#  datetime.date(1994, 6, 24) datetime.date(1994, 8, 29)
#  datetime.date(1995, 4, 17)]
# ['Pixies' 1986 'United States' datetime.date(1988, 3, 21)
#  datetime.date(1988, 3, 21) datetime.date(1989, 4, 17)
#  datetime.date(1990, 8, 13)]
# ['Pulp' 1978 'United Kingdom' datetime.date(1983, 4, 18)
#  datetime.date(1987, 5, 1) datetime.date(1992, 7, 1)
#  datetime.date(1993, 10, 11)]
# ['Radiohead' 1991 'United Kingdom' datetime.date(1993, 2, 22)
#  datetime.date(1994, 11, 29) datetime.date(1995, 5, 17)
#  datetime.date(1997, 5, 21)]
# ['Smashing Pumpkins' 1988 'United States' datetime.date(1991, 5, 28)
#  datetime.date(1993, 1, 1) datetime.date(1993, 7, 26)
#  datetime.date(1994, 10, 4)]
# ['Suicidal Tendencies' 1982 'United States' datetime.date(1983, 7, 5)
#  datetime.date(1987, 6, 21) datetime.date(1987, 7, 26)
#  datetime.date(1988, 9, 13)]
# ['T. Rex' 1967 'United Kingdom' datetime.date(1968, 7, 1)
#  datetime.date(1968, 10, 14) datetime.date(1969, 5, 16)
#  datetime.date(1970, 3, 1)]
# ['Talking Heads' 1974 'United States' datetime.date(1977, 9, 16)
#  datetime.date(1978, 7, 14) datetime.date(1979, 8, 3)
#  datetime.date(1980, 10, 8)]
# ['The Breeders' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['The Jam' 1990 'United States' datetime.date(1991, 2, 8)
#  datetime.date(1991, 2, 11) datetime.date(1991, 8, 27)
#  datetime.date(1991, 11, 14)]
# ['The Stranglers' 1974 'United Kingdom' datetime.date(1977, 4, 15)
#  datetime.date(1977, 9, 23) datetime.date(1978, 5, 12)
#  datetime.date(1979, 9, 21)]
# ['The Verve' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['They Might Be Giants' 1982 'United States' datetime.date(1986, 11, 4)
#  datetime.date(1988, 9, 25) datetime.date(1989, 1, 1)
#  datetime.date(1990, 1, 2)]
# ['Violent Femmes' 1980 'United States' datetime.date(1983, 4, 1)
#  datetime.date(1984, 6, 1) datetime.date(1986, 1, 1)
#  datetime.date(1988, 1, 1)]
# ['Wilco' 1994 'United States' datetime.date(1995, 3, 28)
#  datetime.date(1996, 10, 29) datetime.date(1997, 1, 1)
#  datetime.date(1998, 6, 22)]
# ['Blue Cheer' 1966 'United States' datetime.date(1968, 1, 1)
#  datetime.date(1968, 1, 16) datetime.date(1969, 3, 1)
#  datetime.date(1969, 12, 1)]
# ['The Cars' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['Clash' 1976 'United Kingdom' datetime.date(1977, 4, 8)
#  datetime.date(1978, 11, 10) datetime.date(1979, 12, 14)
#  datetime.date(1980, 1, 1)]
# ['Damn Yankees' 1989 'United States' datetime.date(1990, 1, 1)
#  datetime.date(1990, 2, 22) datetime.date(1992, 9, 25)
#  datetime.date(1993, 1, 1)]
# ['Dream Theater' 1985 'New York' datetime.date(1989, 3, 6)
#  datetime.date(1992, 6, 30) datetime.date(1993, 1, 1)
#  datetime.date(1993, 7, 25)]
# ['Extreme' 1985 'United States' datetime.date(1988, 1, 1)
#  datetime.date(1989, 5, 21) datetime.date(1990, 8, 7)
#  datetime.date(1991, 9, 11)]
# ['Fastway' 1982 'United Kingdom' datetime.date(1983, 1, 1)
#  datetime.date(1984, 1, 1) datetime.date(1985, 1, 1)
#  datetime.date(1986, 1, 1)]
# ['Goo Goo Dolls' 1986 'United States' datetime.date(1987, 9, 13)
#  datetime.date(1989, 2, 1) datetime.date(1990, 10, 16)
#  datetime.date(1993, 2, 23)]
# ['Hanoi Rocks' 1980 'Finland' datetime.date(1981, 2, 1)
#  datetime.date(1982, 1, 1) datetime.date(1982, 1, 1)
#  datetime.date(1983, 1, 1)]
# ['L.A. Guns' 1983 'United States' datetime.date(1988, 1, 1)
#  datetime.date(1989, 8, 19) datetime.date(1991, 6, 25)
#  datetime.date(1994, 10, 5)]
# ['Marillion' 1979 'United Kingdom' datetime.date(1983, 3, 13)
#  datetime.date(1984, 3, 12) datetime.date(1985, 6, 17)
#  datetime.date(1987, 6, 12)]
# ['Midnight Oil' 1976 'Australia' datetime.date(1978, 1, 1)
#  datetime.date(1979, 1, 1) datetime.date(1981, 11, 1)
#  datetime.date(1982, 11, 1)]
# ['Ministry' 1981 'United States' datetime.date(1983, 9, 1)
#  datetime.date(1986, 3, 12) datetime.date(1987, 1, 16)
#  datetime.date(1988, 10, 11)]
# ['The Outlaws' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['Queensrÿche' 1981 'United States' datetime.date(1983, 1, 1)
#  datetime.date(1986, 12, 12) datetime.date(1988, 5, 2)
#  datetime.date(1990, 8, 20)]
# ['Savatage' 1979 'United States' datetime.date(1983, 11, 1)
#  datetime.date(1985, 5, 20) datetime.date(1986, 1, 1)
#  datetime.date(1987, 1, 1)]
# ['Sepultura' 1984 'Brazil' datetime.date(1985, 12, 1)
#  datetime.date(1986, 11, 10) datetime.date(1987, 10, 30)
#  datetime.date(1989, 1, 1)]
# ['Slayer' 1981 'United States' datetime.date(1983, 12, 1)
#  datetime.date(1985, 3, 1) datetime.date(1985, 5, 1)
#  datetime.date(1986, 10, 7)]
# ['Sonic Youth' 1981 'United States' datetime.date(1983, 1, 1)
#  datetime.date(1985, 1, 1) datetime.date(1986, 5, 1)
#  datetime.date(1987, 6, 1)]
# ['Status Quo' 1967 'United Kingdom' datetime.date(1968, 9, 1)
#  datetime.date(1969, 8, 1) datetime.date(1970, 8, 1)
#  datetime.date(1971, 1, 1)]
# ['Stryper' 1983 'United States' datetime.date(1984, 8, 10)
#  datetime.date(1985, 1, 1) datetime.date(1985, 5, 15)
#  datetime.date(1986, 1, 21)]
# ['Tesla' 1981 'United States' datetime.date(1986, 12, 8)
#  datetime.date(1989, 2, 1) datetime.date(1990, 6, 27)
#  datetime.date(1990, 11, 13)]
# ['The Cult' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['The Fabulous Thunderbirds' 1974 'United States'
#  datetime.date(1979, 1, 1) datetime.date(1980, 1, 1)
#  datetime.date(1981, 1, 1) datetime.date(1982, 1, 1)]
# ['The Guess Who' 1962 'Canada' datetime.date(1965, 1, 1)
#  datetime.date(1965, 1, 1) datetime.date(1966, 1, 1)
#  datetime.date(1968, 1, 1)]
# ['The Lemonheads' 1984 'United States' datetime.date(1987, 1, 1)
#  datetime.date(1988, 1, 1) datetime.date(1989, 1, 1)
#  datetime.date(1989, 5, 1)]
# ['The Moody Blues' 1964 'United Kingdom' datetime.date(1965, 7, 23)
#  datetime.date(1967, 11, 11) datetime.date(1968, 7, 26)
#  datetime.date(1969, 1, 1)]
# ['The Outfield' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['The Pogues' 1982 'United Kingdom' datetime.date(1984, 1, 1)
#  datetime.date(1985, 1, 1) datetime.date(1988, 1, 1)
#  datetime.date(1989, 7, 25)]
# ['The Scorpions' 1965 'Germany' datetime.date(1972, 1, 1)
#  datetime.date(1974, 1, 1) datetime.date(1975, 1, 1)
#  datetime.date(1976, 1, 1)]
# ['The Tubes' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['The Zombies' 1960 'United Kingdom' datetime.date(1963, 3, 22)
#  datetime.date(1963, 11, 22) datetime.date(1964, 1, 10)
#  datetime.date(1964, 1, 20)]
# ['Toto' 1977 'United States' datetime.date(1978, 10, 10)
#  datetime.date(1979, 10, 26) datetime.date(1981, 1, 1)
#  datetime.date(1982, 4, 8)]
# ['Tygers of Pan Tang' 1978 'United Kingdom' datetime.date(1980, 1, 1)
#  datetime.date(1981, 4, 10) datetime.date(1981, 11, 3)
#  datetime.date(1982, 1, 1)]
# ['Van Der Graaf Generator' 1967 'United Kingdom' datetime.date(1969, 9, 1)
#  datetime.date(1970, 2, 1) datetime.date(1970, 12, 1)
#  datetime.date(1971, 10, 1)]
# ['W.A.S.P.' 1982 'United States' datetime.date(1984, 8, 17)
#  datetime.date(1985, 10, 1) datetime.date(1986, 11, 21)
#  datetime.date(1987, 11, 27)]
# ['War' 1969 'United States' datetime.date(1970, 1, 1)
#  datetime.date(1970, 1, 1) datetime.date(1971, 1, 1)
#  datetime.date(1971, 2, 1)]
# ['Ween' 1984 'United States' datetime.date(1986, 1, 1)
#  datetime.date(1987, 1, 1) datetime.date(1988, 1, 1)
#  datetime.date(1988, 1, 1)]
# ['Yardbirds' 1963 'United Kingdom' datetime.date(1965, 1, 1)
#  datetime.date(1965, 7, 5) datetime.date(1965, 11, 15)
#  datetime.date(1966, 8, 8)]

# %%
test.isna().sum()
# Out:
# name         0
# form_date    0
# location     0
# release_1    0
# release_2    0
# release_3    0
# release_4    0
# dtype: int64

# %%
test.to_csv('band_unit_test.csv',index=False)

# %%
music.set_useragent("YourAppName", "1.0", "your-email@example.com")

# %%
music.search_artists(artist='Nirvana')

# %%
music.musicbrainz.VALID_SEARCH_FIELDS
# Out:
# {'annotation': ['entity', 'name', 'text', 'type'],
#  'area': ['aid',
#   'alias',
#   'area',
#   'areaaccent',
#   'begin',
#   'comment',
#   'end',
#   'ended',
#   'iso',
#   'iso1',
#   'iso2',
#   'iso3',
#   'sortname',
#   'tag',
#   'type'],
#  'artist': ['alias',
#   'area',
#   'arid',
#   'artist',
#   'artistaccent',
#   'begin',
#   'beginarea',
#   'comment',
#   'country',
#   'end',
#   'endarea',
#   'ended',
#   'gender',
#   'ipi',
#   'isni',
#   'primary_alias',
#   'sortname',
#   'tag',
#   'type'],
#  'event': ['aid',
#   'alias',
#   'area',
#   'arid',
#   'artist',
#   'begin',
#   'comment',
#   'eid',
#   'end',
#   'ended',
#   'event',
#   'eventaccent',
#   'pid',
#   'place',
#   'tag',
#   'type'],
#  'instrument': ['alias',
#   'comment',
#   'description',
#   'iid',
#   'instrument',
#   'instrumentaccent',
#   'tag',
#   'type'],
#  'label': ['alias',
#   'area',
#   'begin',
#   'code',
#   'comment',
#   'country',
#   'end',
#   'ended',
#   'ipi',
#   'label',
#   'labelaccent',
#   'laid',
#   'release_count',
#   'sortname',
#   'tag',
#   'type'],
#  'place': ['address',
#   'alias',
#   'area',
#   'begin',
#   'comment',
#   'end',
#   'ended',
#   'lat',
#   'long',
#   'pid',
#   'place',
#   'placeaccent',
#   'type'],
#  'recording': ['alias',
#   'arid',
#   'artist',
#   'artistname',
#   'comment',
#   'country',
#   'creditname',
#   'date',
#   'dur',
#   'format',
#   'isrc',
#   'number',
#   'position',
#   'primarytype',
#   'qdur',
#   'recording',
#   'recordingaccent',
#   'reid',
#   'release',
#   'rgid',
#   'rid',
#   'secondarytype',
#   'status',
#   'tag',
#   'tid',
#   'tnum',
#   'tracks',
#   'tracksrelease',
#   'type',
#   'video'],
#  'release-group': ['alias',
#   'arid',
#   'artist',
#   'artistname',
#   'comment',
#   'creditname',
#   'primarytype',
#   'reid',
#   'release',
#   'releasegroup',
#   'releasegroupaccent',
#   'releases',
#   'rgid',
#   'secondarytype',
#   'status',
#   'tag',
#   'type'],
#  'release': ['alias',
#   'arid',
#   'artist',
#   'artistname',
#   'asin',
#   'barcode',
#   'catno',
#   'comment',
#   'country',
#   'creditname',
#   'date',
#   'discids',
#   'discidsmedium',
#   'format',
#   'label',
#   'laid',
#   'lang',
#   'mediums',
#   'primarytype',
#   'quality',
#   'reid',
#   'release',
#   'releaseaccent',
#   'rgid',
#   'script',
#   'secondarytype',
#   'status',
#   'tag',
#   'tracks',
#   'tracksmedium',
#   'type'],
#  'series': ['alias',
#   'comment',
#   'orderingattribute',
#   'series',
#   'seriesaccent',
#   'sid',
#   'tag',
#   'type'],
#  'work': ['alias',
#   'arid',
#   'artist',
#   'comment',
#   'iswc',
#   'lang',
#   'recording',
#   'recording_count',
#   'rid',
#   'tag',
#   'type',
#   'wid',
#   'work',
#   'workaccent']}

# %%
m
